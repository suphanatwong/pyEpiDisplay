# %%
#Install pyreadr library
#!pip install pyreadr

# %%
#Load pyreadr library
import pyreadr as pr

# %%
#Load dataset
file_path = "/Users/stlp/Documents/OutbreakDataset.RData"

result = pr.read_r(file_path)
print(type(result))
result
#df = result['Outbreak']  # replace 'Outbreak' with the object name saved in R
#df.head()
# Out:
# ---------------------------------------------------------------------------
# PyreadrError                              Traceback (most recent call last)
# Cell In[13], line 3
#       1 #Load dataset
#       2 file_path = "/Users/stlp/Documents/OutbreakDataset.RData"
# ----> 3 result = pr.read_r(file_path)
#       4 print(type(result))
#       5 result
#
# File ~/miniconda3/lib/python3.13/site-packages/pyreadr/pyreadr.py:65, in read_r(path, use_objects, timezone)
#      63 filename_bytes = os.path.expanduser(filename_bytes)
#      64 if not os.path.isfile(filename_bytes):
# ---> 65     raise PyreadrError("File {0} does not exist!".format(filename_bytes))
#      66 parser.parse(filename_bytes)
#      68 result = OrderedDict()
#
# PyreadrError: File b'/Users/stlp/Documents/OutbreakDataset.RData' does not exist!

# %%
import glob
import pyreadr
 
# find any file matching OutbreakDataset.*
files = glob.glob(r"C:\Users\stlp\Documents\*")
 
if files:
    print(f"Loading file: {files[0]}")
    loadr = pyreadr.read_r(files[0])  # read the first match
else:
    print("No file found matching the pattern.")
# Out:
# No file found matching the pattern.
